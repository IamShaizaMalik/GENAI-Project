# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# **Data Preprocessing**

# %%
import os

base_path = "/content/drive/MyDrive/Colab Notebooks/GenAIproject/COLIEE2025statute_data-English"
train_folder = os.path.join(base_path, "train")
text_folder = os.path.join(base_path, "text")

# %%
import os

# Print all XML filenames
for filename in os.listdir(train_folder):
    if filename.endswith(".xml"):
        print(filename)
# Out:
# riteval_H18_jp.xml
# riteval_H19_jp.xml
# riteval_H20_jp.xml
# riteval_H21_jp.xml
# riteval_H23_jp.xml
# riteval_H24_jp.xml
# riteval_H27_jp.xml
# riteval_H28_jp.xml
# riteval_H30_jp.xml
# riteval_R01_jp.xml
# riteval_R04_jp.xml
# riteval_R05_jp.xml
# riteval_H29_jp.xml
# riteval_R02_jp.xml
# riteval_H25_jp.xml
# riteval_H26_jp.xml
# riteval_H22_jp.xml
# riteval_R03_jp.xml

# %%
import os

xml_files = [f for f in os.listdir(train_folder) if f.endswith(".xml")]
sample_file = os.path.join(train_folder, xml_files[0])
print(f"Inspecting: {sample_file}")

import xml.etree.ElementTree as ET

# Load and parse the file
tree = ET.parse(sample_file)  # make sure sample_file has the correct path
root = tree.getroot()

# Print the full XML structure to inspect
ET.dump(root)
# Out:
# Inspecting: /content/drive/MyDrive/Colab Notebooks/GenAIproject/COLIEE2025statute_data-English/train/riteval_H18_jp.xml
# <dataset>
# <pair id="H18-1-1" label="Y">
# <t1>
# Article 572: Even if the seller has made a special agreement to the effect that he/she will not be liable for the warranty in the cases provided for in the main text of Article 562, paragraph 1 or Article 565, he/she cannot be exempt from liability for facts that he/she knew but did not disclose, and for rights that he/she established for a third party or transferred to a third party.
# </t1>
# <t2>
# A special agreement exempting the seller from warranty liability can be made, but even in that case, if the seller has established rights for a third party regarding the subject matter, the seller cannot be exempt from liability.
# </t2>
# </pair>
#
# <pair id="H18-1-2" label="N">
# <t1>
# Article 565: The provisions of the preceding three articles shall apply mutatis mutandis to cases where the rights transferred by the seller to the buyer do not conform to the contents of the contract (including cases where a part of the rights belongs to another person and the part of the rights is not transferred).
# Article 566: If the seller delivers to the buyer an object that does not conform to the contents of the contract in terms of type or quality, and the buyer does not notify the seller to that effect within one year from the time the buyer becomes aware of the non-conformity, the buyer cannot claim for completion of performance, claim for reduction of the price, claim damages, or cancel the contract on the grounds of the non-conformity. However, this does not apply if the seller knew of the non-conformity at the time of delivery or did not know of it due to gross negligence.
# </t1>
# <t2>
# There is a time limit for pursuing liability for guarantee when the subject matter is restricted by a superficies right, but there is no time limit for pursuing liability for guarantee when the buyer loses his rights due to the exercise of a mortgage.
#
# </t2>
# </pair>
#
# <pair id="H18-1-3" label="N">
# <t1>
# Article 568: A purchaser at an auction based on the provisions of the Civil Execution Act or other laws (hereinafter referred to simply as "auction" in this Article) may cancel the contract or request a reduction in the purchase price from the debtor pursuant to the provisions of Articles 541 and 542 and Article 563 (including the case where Article 565 applies mutatis mutandis).
# 2. In the case of the preceding paragraph, if the debtor is insolvent, the purchaser may request the creditor who has received a share of the purchase price to return all or part of the purchase price.
# 3. In the cases of the preceding two paragraphs, if the debtor knows that the thing or right does not exist but fails to make a claim, or if the creditor knows that but demands an auction, the purchaser may claim damages from these persons.
# 4. The provisions of the preceding three paragraphs do not apply to non-conformity regarding the type or quality of the object of the auction.
#
# </t1>
# <t2>
# Since a forced auction is also a sale, the warranty liability is imposed in the same way as in a normal sale.
#
# </t2>
# </pair>
#
# <pair id="H18-2-1" label="Y">
# <t1>
# Article 697. A person who begins to manage affairs for another person without obligation (hereinafter referred to as the "manager" in this chapter) must manage those affairs (hereinafter referred to as the "management of affairs") in a manner that best suits the interests of the other person according to the nature of the affairs.
# 2. When the manager knows or can infer the intention of the other person, he must manage the affairs in accordance with that intention.
# </t1>
# <t2>
# Even if you repair a neighbor's fence to protect your own house, you are deemed to have the intention to do so for the benefit of others.
# </t2>
# </pair>
#
# <pair id="H18-2-2" label="Y">
# <t1>
# Article 698: If a manager manages affairs in order to prevent imminent harm to the person's body, reputation, or property, he or she will not be liable for compensation for damages caused by this, unless there is malice or gross negligence.
# </t1>
# <t2>
# If a person pushes away a person who is about to be hit by a car to save him or her, but the person's expensive kimono is stained, there is no need to pay compensation for damages for the kimono.
# </t2>
# </pair>
#
# <pair id="H18-2-3" label="N">
# <t1>
# Article 698: When a manager manages affairs in order to prevent imminent harm to the person's body, reputation, or property, he/she shall not be liable for compensation for damages resulting therefrom, unless there is malice or gross negligence.
#
# </t1>
# <t2>
# A manager must manage affairs with the same care as he/she would take for his/her own property.
#
# </t2>
# </pair>
#
# <pair id="H18-2-4" label="Y">
# <t1>
# Article 702: When a manager incurs expenses beneficial to the person, he/she may request reimbursement from the person.
# 2. The provisions of Article 650, paragraph 2 shall apply mutatis mutandis to cases in which a manager incurs beneficial debts for the person.
# 3. If the manager manages affairs against the will of the person in question, the provisions of the preceding two paragraphs shall apply only to the extent that the person in question is actually benefiting from them.
#
# </t1>
# <t2>
# If a neighbor's fence that collapsed during a typhoon is repaired, but the neighboring house was planning to replace it with a block wall, if the repaired part collapses again the following week due to another typhoon, the person in question will not be able to claim reimbursement for the repair costs.
#
# </t2>
# </pair>
#
# <pair id="H18-2-5" label="N">
# <t1>
# Article 697. A person who begins to manage affairs for another person without obligation (hereinafter referred to as the "manager" in this chapter) must manage the affairs (hereinafter referred to as the "management of affairs") in a manner that best suits the interests of the person in question, according to the nature of the affairs.
#
# 2. If the manager knows or can infer the will of the person in question, he or she must manage the affairs in accordance with that will.
# </t1>
# <t2>
# Management of affairs is also established when a parent, acting as a legal representative, manages the affairs of a child based on the parent's legal authority.
#
# </t2>
# </pair>
#
# <pair id="H18-3-2" label="Y">
# <t1>
# Article 715: A person who employs another person for a business is liable to compensate a third party for damages caused by the employee in the execution of that business. However, this does not apply if the employer exercised reasonable care in selecting the employee and supervising the business, or if damages would have occurred even if the employer had exercised reasonable care.
# 2. A person who supervises a business on behalf of an employer is also liable under the preceding paragraph.
# 3. The provisions of the preceding two paragraphs do not prevent an employer or supervisor from exercising a right of recourse against an employee.
#
# </t1>
# <t2>
# An employer is exempt from liability if he proves that he exercised reasonable care in selecting and supervising an employee.
# </t2>
# </pair>
#
# <pair id="H18-3-4" label="Y">
# <t1>
# Article 715: A person who employs another person for a business is liable to compensate a third party for damages caused by the employee in the execution of that business. However, this does not apply if the employer exercised reasonable care in selecting the employee and supervising the business, or if damages would have occurred even if the employer had exercised reasonable care.
# 2. A person who supervises a business on behalf of the employer is also liable under the preceding paragraph.
# 3. The provisions of the preceding two paragraphs do not prevent the employer or supervisor from exercising a right of recourse against the employee.
# </t1>
# <t2>
# Even if the victim proves that the employer granted supervisory authority to the substitute supervisor prior to the employee's harmful act, the substitute supervisor is exempt from liability if he proves that he exercised reasonable care in selecting and supervising the employee.
# </t2>
# </pair>
#
# <pair id="H18-9-1" label="Y">
# <t1>
# Article 175: No real rights may be created other than those provided for in this Act or other laws.
# Article 265: A surface right holder has the right to use the land of another person in order to own structures or bamboo or trees on that land.
# Article 270: An emphyteusis has the right to cultivate or raise livestock on the land of another person by paying rent.
# Article 280: A holder of an easement has the right to use the land of another person for the benefit of his own land in accordance with the purpose specified in the act of establishment. However, this must not violate the provisions of Chapter 3, Section 1 (Limits of Ownership) (limited to those related to the public order).
# </t1>
# <t2>
# Usufruct rights are established only on real property.
# </t2>
# </pair>
#
# <pair id="H18-9-2" label="N">
# <t1>
# Article 295: If a possessor of another person's property has a claim arising in relation to that property, he may retain that property until that claim is satisfied. However, this does not apply if the claim is not due.
# 2: The provisions of the preceding paragraph do not apply if possession began through a tort.
# Article 303: A person with a lien has the right to receive satisfaction of his/her claim from the debtor's property in preference to other creditors, in accordance with the provisions of this Act and other laws.
# Article 388: If land and a building existing thereon belong to the same owner, and a mortgage is established on the land or building, and the execution of the mortgage results in a different owner, a surface right is deemed to have been established on the building. In this case, the rent shall be determined by the court at the request of the parties. </t1>
# <t2>
# There are legal security rights, but no legal usufruct rights.
#
# </t2>
# </pair>
#
# <pair id="H18-9-3" label="N">
# <t1>
# Article 329: In the event that general liens conflict with each other, the order of priority shall follow the order set forth in each item of Article 306.
# 2: In the event that a general lien conflicts with a special lien, the special lien shall take precedence over the general lien. However, a lien for the expenses of common benefits shall have the effect of taking precedence over all creditors who have received the benefit.
# Article 306: A person who has a claim arising from the causes listed below shall have a lien over the debtor's total assets.
# 1. Expenses for the common good
# 2. Employment relations
# 3. Funeral expenses
# 4. Supply of daily necessities
# Article 330: In the event that special statutory liens compete with each other for the same movable property, the order of priority shall be in the following order. In this case, if there are several custodians of the statutory lien for the preservation of the movable property listed in item 2, the later custodian shall have priority over the earlier custodian.
# 1. Lien for rental of real estate, lodging at hotels, and transportation
# 2. Lien for the preservation of movable property
# 3. Lien for the sale and purchase of movable property, supply of seeds or fertilizers, agricultural labor, and industrial labor
# 2. In the case of the preceding paragraph, if the first-ranked statutory lien holder knew at the time of acquiring the claim that there were second-ranked or third-ranked statutory lien holders, he/she cannot exercise his/her priority against these persons. The same shall apply to the person who preserved the thing for the first-ranked statutory lien holder. 3. With regard to fruits, the first priority belongs to those engaged in agricultural labor, the second to the supplier of seeds or fertilizer, and the third to the lessor of the land.
#
# </t1>
# <t2>
# In the case of real rights that do not need to be perfected, the real right that was established first in time takes precedence.
#
# </t2>
# </pair>
#
# <pair id="H18-15-1" label="N">
# <t1>
# Article 398-20 The principal secured by a mortgage shall be fixed in the following cases.
# 1. When a mortgagee files an application for auction or execution of proceeds from secured real estate, or attachment pursuant to the provisions of Article 304 as applied mutatis mutandis in Article 372, with respect to the mortgaged real estate. However, this applies only when an auction procedure or execution of proceeds from secured real estate has commenced or an attachment has occurred.
# 2. When a mortgagee has effected an attachment of the mortgaged real estate as a disposition for default on collections.
# 3. When two weeks have passed since the mortgagee learned that an auction procedure had commenced or an attachment had occurred with respect to the mortgaged real estate as a disposition for default on collections.
# 4. When the debtor or the mortgagee has received a ruling for the commencement of bankruptcy proceedings.
# 2. When the effect of the commencement of auction procedures or attachment under item 3 of the preceding paragraph or the decision to commence bankruptcy procedures under item 4 of the same paragraph has ceased, the principal to be secured shall be deemed not to have been determined. However, this shall not apply if there is a person who has acquired the mortgage or the right which is the subject of the mortgage as if the principal had been determined.
# </t1>
# <t2>
# Even if the auction procedures filed by the junior secured creditor for the subject real estate have commenced, the first-ranked mortgagee has priority over the junior secured creditor in selecting the time of the auction, and may therefore stop the auction procedures without determining the principal.
# </t2>
# </pair>
# <pair id="H18-15-2" label="N">
# <t1>
# Article 398-3. A mortgagee may exercise his mortgage for the entire amount of the determined principal, interest and other periodic payments, and compensation for damages caused by non-performance of the obligation, up to the maximum amount.
# 2. In the case where the claim on a bill or check acquired without a transaction with the debtor is the claim secured by the root mortgage, if any of the following events occur, the root mortgage can only be exercised for those acquired before the event. However, this does not prevent the exercise of the root mortgage for those acquired after the event, even if they were acquired without knowledge of the event.
# 1. Suspension of payment by the debtor
# 2. Petition for the commencement of bankruptcy proceedings, rehabilitation proceedings, reorganization proceedings, or special liquidation proceedings against the debtor
# 3. Petition for auction of the mortgaged real estate or seizure due to collection disposition
# </t1>
# <t2>
# Since a root mortgage is treated the same as an ordinary mortgage once the principal is determined, the portion of the interest and damages of the secured claim that are secured by the root mortgage is limited to the last two years.
# </t2>
# </pair>
#
# <pair id="H18-15-3" label="N">
# <t1>
# Article 398-2 Mortgages may be established to secure unspecified claims within a certain range up to a maximum amount, as provided for in the establishment act.
# 2 The scope of unspecified claims to be secured by a mortgage under the provisions of the preceding paragraph (hereinafter referred to as a "root mortgage") must be limited to those arising from a specific continuous transaction contract with the debtor or other certain types of transactions with the debtor.
# 3 Claims that continue to arise between the debtor based on a specific cause, or claims on bills or checks, or electronically recorded claims (meaning electronically recorded claims as provided for in Article 2, paragraph 1 of the Electronically Recorded Claims Act (Act No. 102 of 2007); the same applies in paragraph 2 of the following article) may be secured by a root mortgage, notwithstanding the provisions of the preceding paragraph.
# </t1>
# <t2>
# The limit of the priority of a mortgage is determined by the maximum amount, and since junior secured creditors and general creditors have no interest in what credits are secured, the limitation of the scope of secured credits is aimed solely at protecting the mortgagor.
#
# </t2>
# </pair>
#
# <pair id="H18-15-4" label="N">
# <t1>
# Article 398-7: A person who acquires a credit from a mortgagee before the principal is fixed cannot exercise a mortgage on that credit. The same applies to a person who makes a payment for or on behalf of the debtor before the principal is fixed.
# 2: If a debt is assumed before the principal is fixed, the mortgagee cannot exercise the mortgage on the debt of the assumer.
# 3. In the case where a dischargeable assumption of debt occurs before the principal is fixed, the creditor cannot transfer the mortgage to the debt borne by the assumer, notwithstanding the provisions of Article 472-4, paragraph 1.
# 4. In the case where a renewal occurs due to a change of creditor before the principal is fixed, the creditor before the renewal cannot transfer the mortgage to the debt after the renewal, notwithstanding the provisions of Article 518, paragraph 1. The same applies to the creditor in the case where a renewal occurs due to a change of debtor before the principal is fixed.
#
# </t1>
# <t2>
# Even before the principal of a mortgage is fixed, a third party who has paid all of the secured debts that are due for repayment may exercise the mortgage in lieu of the mortgagee in order to secure the right of reimbursement against the debtor.
# </t2>
# </pair>
#
# <pair id="H18-15-5" label="Y">
# <t1>
# Article 398-12　Before the principal is fixed, a mortgagee may transfer his/her mortgage with the consent of the mortgagor.
# 2　A mortgagee may divide his/her mortgage into two mortgages and transfer one of them in accordance with the provisions of the preceding paragraph. In this case, the right that is the object of the mortgage shall be extinguished with respect to the mortgage that is transferred.
# 3　In order to transfer in accordance with the provisions of the preceding paragraph, the consent of the person who has the right that is the object of the mortgage must be obtained.
# Article 398-13 Before the principal is fixed, a mortgagee may, with the consent of the mortgagor, transfer a part of the mortgage (meaning that the transferor transfers the mortgage without dividing it in order to jointly own it with the transferee. The same applies in this section).
# </t1>
# <t2>
# Before the principal is fixed, a mortgage is a control right over the maximum amount of value that is separate from the secured claim, so it can be transferred in whole or in part, but since the debtor and secured claim may change, the consent of the mortgagor must be obtained.
# </t2>
# </pair>
# <pair id="H18-20-1" label="N">
# <t1>
# Article 9 Legal acts of an adult ward may be revoked. However, this does not apply to the purchase of daily necessities and other acts related to daily life.
# </t1>
# <t2>
# If an adult ward receives a building as a gift, the adult ward cannot cancel the gift contract.
#
# </t2>
# </pair>
#
# <pair id="H18-20-2" label="Y">
# <t1>
# Article 9: Legal acts of an adult ward may be revoked. However, this does not apply to purchases of daily necessities and other acts related to daily life.
# Article 120: An act that can be revoked due to a limited capacity may be revoked only by a person with limited capacity (including the other person with limited capacity in the case of an act performed as the legal representative of another person with limited capacity), or their agent, successor, or a person who can give consent.
# 2: An act that can be revoked due to fraud or duress may be revoked only by the person who made the defective manifestation of intention, or their agent or successor.
# </t1>
# <t2>
# When an adult ward performs a legal act other than an act related to daily life, the adult ward may cancel the legal act even if the adult ward has obtained the consent of the adult guardian beforehand.
# </t2>
# </pair>
#
# <pair id="H18-20-3" label="N">
# <t1>
# Article 7: With regard to a person who is in a constant state of lacking the ability to appreciate facts and circumstances due to a mental disability, the family court may make a ruling on the commencement of guardianship at the request of the person himself/herself, spouse, relative within the fourth degree of kinship, guardian of a minor, guardianship supervisor of a minor, curator, curator supervisor, assistant, assistant supervisor, or public prosecutor.
# </t1>
# <t2>
# With regard to a minor for whom a guardian of a minor has been appointed, a ruling on the commencement of guardianship cannot be made to appoint an adult guardian.
# </t2>
# </pair>
#
# <pair id="H18-21-2" label="N">
# <t1>
# Article 152: When a right is acknowledged, the prescription begins to run anew from that time.
# 2. In order to acknowledge the preceding paragraph, it is not necessary that the party is not restricted in his or her capacity to act or has the authority to dispose of the other party's right.
# Article 153: The suspension or renewal of the prescription under Article 147 or Article 148 shall be effective only between the party in respect of which the reason for suspension or renewal arose and their successors.
# 2. The postponement of the completion of prescription pursuant to the provisions of Articles 149 to 151 shall be effective only between the parties in respect of whom the grounds for the postponement of completion arose and their successors.
# 3. The renewal of the prescription pursuant to the provisions of the preceding Article shall be effective only between the parties in respect of whom the grounds for the renewal arose and their successors.
# Article 458. The provisions of Articles 438, Article 439, paragraph 1, Articles 440, and Article 441 shall apply mutatis mutandis to grounds arising with respect to a guarantor who is jointly and severally liable with the principal debtor.
# Article 441: Except as provided for in Article 438, Article 439, paragraph 1, and the previous article, an event occurring with respect to one of the joint debtors shall not have any effect on the other joint debtors. However, if the creditor and one of the other joint debtors express a different intention, the effect on the other joint debtors shall be in accordance with that intention.
# </t1>
# <t2>
# With respect to A's claim against B, if the joint guarantor C acknowledges A before the expiration of the prescription period, the effect of interruption of the prescription shall also extend to the principal debtor B.
# </t2>
# </pair>
# <pair id="H18-21-3" label="Y">
# <t1>
# Article 169: With respect to rights established by a final and binding judgment or one having the same effect as a final and binding judgment, the prescription period shall be ten years, even if a prescription period shorter than ten years is provided for.
# 2. The provisions of the preceding paragraph do not apply to claims that are not yet due at the time of confirmation.
#
# </t1>
# <t2>
# When a civil settlement is reached in which the debtor makes installment payments for a claim arising from a commercial transaction that has become overdue, the prescription period for the claim is 10 years.
#
# </t2>
# </pair>
#
# <pair id="H18-23-I" label="Y">
# <t1>
# (Contracts on behalf of a third party)※
# Article 537. When one of the parties undertakes to perform a certain service to a third party, the third party has the right to demand the performance directly from the debtor.
#
# 2. The contract in the preceding paragraph shall not be affected even if the third party does not actually exist or is not specified at the time of its formation.
#
# 3. In the case of paragraph 1, the third party's right arises when the third party expresses his/her intention to enjoy the benefits of the contract in the same paragraph to the debtor.
# </t1>
# <t2>
# If A sells a jewel to B and B pays the price to C, and C expresses his intention to receive the benefit, and A delivers the jewel to B, but if B does not pay the price to C, C can demand that B pay the price to himself, but A can also demand that B pay the price to C.
#
# </t2>
# </pair>
#
# <pair id="H18-23-U" label="N">
# <t1>
# Article 537: When one of the parties under a contract promises to perform a certain performance to a third party, the third party has the right to claim that performance directly from the debtor.
# 2: The validity of the contract in the preceding paragraph shall not be hindered even if the third party does not actually exist or has not been specified at the time of its formation.
# 3: In the case of paragraph 1, the third party's rights arise when the third party expresses to the debtor his intention to enjoy the benefits of the contract in the same paragraph.
# Article 538: After the third party's rights arise pursuant to the provisions of the preceding article, the parties cannot modify or extinguish them.
# 2: If the debtor fails to perform the debt to the third party after the third party's rights arise pursuant to the provisions of the preceding article, the other party to the contract in paragraph 1 of the same article cannot terminate the contract without the consent of the third party.
# </t1>
# <t2>
# If A sells a jewel to B and B pays the proceeds to C to repay a loan debt owed jointly and severally by A and D to C, if D has already repaid the debt to C, A may terminate the contract with B by mutual consent, even after C has expressed its intention to receive the benefit.
#
# </t2>
# </pair>
#
# <pair id="H18-25-E" label="Y">
# <t1>
# Article 107: If an agent performs an act within the scope of his/her power of agency for the purpose of benefiting himself/herself or a third party, and the other party knows or could know the purpose, the act shall be deemed to have been performed by a person without power of agency.
# Article 109: A person who has indicated to a third party that he/she has granted power of agency to another person shall be liable for any act performed by that other person with the third party within the scope of the power of agency. However, this shall not apply if the third party knows, or is negligent in not knowing, that the other person has not been granted power of agency.
# Article 110: The provisions of the main text of the first paragraph of the preceding Article shall apply mutatis mutandis to cases where an agent acts outside of his/her authority and a third party has a legitimate reason to believe that the agent has the authority.
#
# </t1>
# <t2>
# A person who has represented to a third party that he/she has given the power of agency to another person may avoid liability for apparent agency by proving that the third party knew or was negligent in not knowing that the other person had not been given the power of agency.
#
# </t2>
# </pair>
#
# <pair id="H18-26-1" label="Y">
# <t1>
# Article 255: When one of the co-owners renounces his/her share or dies without an heir, that share shall belong to the other co-owner.
#
# </t1>
# <t2>
# If A and B share Building A in the ratio of 1/2 each, when A dies without an heir or special relative, the ownership of Building A shall belong to B.
# </t2>
# </pair>
#
# <pair id="H18-26-5" label="Y">
# <t1>
# Article 254: Any claim that one of the co-owners has against the other co-owners regarding the property may also be exercised against the specific successor.
#
# </t1>
# <t2>
# If A pays in advance for the maintenance costs of a building that A and B share, A may request payment of the advance from C, who has taken over the co-ownership interest from B.
#
# </t2>
# </pair>
#
# <pair id="H18-27-U" label="N">
# <t1>
# Article 485: If there is no other intention expressed regarding the costs of payment, the costs shall be borne by the debtor. However, if the creditor increases the costs of payment by moving his/her address or other actions, the increased amount shall be borne by the creditor.
# </t1>
# <t2>
# If the obligee of a debt to be brought moves far away before the due date of performance, the debtor shall bear the transportation costs of the object.
#
# </t2>
# </pair>
#
# <pair id="H18-28-1" label="N">
# <t1>
# Article 446: The guarantor is responsible for the performance of the debt when the principal obligor fails to perform the debt.
#
# 2. A guarantee contract shall not be effective unless it is in writing.
#
# 3. If a guarantee contract is made by an electromagnetic record (a record made in an electronic, magnetic or other form that cannot be recognized by human perception and used for information processing by a computer) that records the contents of the guarantee contract, the guarantee contract shall be deemed to have been made in writing, and the provisions of the preceding paragraph shall apply.
#
# </t1>
# <t2>
# A joint guarantee contract shall not be effective unless it is in writing, but a simple guarantee contract shall be effective even if it is not in writing.
# </t2>
# </pair>
#
# <pair id="H18-28-2" label="Y">
# <t1>
# Article 465-2: The guarantor of a guarantee contract (hereinafter referred to as a "revolving guarantee contract") in which the principal obligation is an unspecified obligation falling within a certain scope and the guarantor is not a corporation (hereinafter referred to as a "personal revolving guarantee contract") shall be liable for the performance of the principal of the principal obligation, the interest on the principal obligation, the penalty, damages, and all other matters incidental to the obligation, as well as the amount of the penalty or damages agreed upon for the insured obligation, up to the maximum amount pertaining to all of them.
#
# 2. A personal revolving guarantee contract shall not be effective unless the maximum amount prescribed in the preceding paragraph is specified.
# </t1>
# <t2>
# When a guarantee contract is made with the purchase obligation arising from a continuous sales contract as the principal obligation, the principal obligation, the penalty, damages, and all other items incidental to the obligation, and the amount of the penalty or damages agreed upon for the guarantee obligation, the guarantee contract will not be effective unless a maximum amount is determined.
#
# </t2>
# </pair>
#
# <pair id="H18-28-3" label="Y">
# <t1>
# Article 465-4: In the following cases, the principal of the principal obligation in a guarantee contract for loans, etc. shall be fixed. However, in the case of item 1, this shall apply only when the procedure for compulsory execution or enforcement of a security interest has commenced.
#
# 1. When the creditor files a petition for compulsory execution or enforcement of a security interest on the property of the principal debtor or guarantor for a claim for the payment of money.
# 2. When the principal debtor or guarantor receives a ruling to commence bankruptcy proceedings.
#
# 3. When the principal debtor or guarantor dies.
#
# </t1>
# <t2>
# When a creditor files a petition for compulsory execution of a claim for payment of money against the principal debtor's assets and a ruling to commence such proceedings is made, the principal of the principal debt under the loan guarantee contract is determined at the time of the petition.
# </t2>
# </pair>
#
# <pair id="H18-28-4" label="N">
# <t1>
# Article 465-3: "In a personal guarantee contract that includes in its scope the debt incurred by lending money or discounting bills (hereinafter referred to as "loan debt") (hereinafter referred to as "personal loan guarantee contract"), if the date on which the principal of the principal debt is to be determined (hereinafter referred to as the "principal determination date") is set to be a date that is later than five years from the date of the conclusion of the personal loan guarantee contract, the provision on the principal determination date shall not be effective.
# 2. In the case where the principal determination date is not set in the personal loan guarantee contract (including the case where the provision on the principal determination date does not take effect pursuant to the provisions of the preceding paragraph), the principal determination date shall be the date that is three years from the date of the conclusion of the personal loan guarantee contract. </t1>
# <t2>
# In the case of a basic guarantee contract in which the principal obligation is a loan obligation and the guarantor is an individual, if the due date for the determination of the principal is set to be four years from the date of the contract, the due date for the determination of the principal shall be three years from the date of the contract.
# </t2>
# </pair>
#
# <pair id="H18-29-4" label="N">
# <t1>
# Article 419: In the case of a breach of an obligation which is intended to provide money, the amount of damages shall be determined by the statutory interest rate. However, if the contracted interest rate exceeds the statutory interest rate, the contracted interest rate shall apply.
# 2. In the case of damages under the preceding paragraph, the creditor is not required to provide proof of damages.
# 3. In the case of damages under the first paragraph, the debtor may not raise the defense of force majeure.
# </t1>
# <t2>
# In a claim for damages based on a delay in the performance of a loan claim, Y will be relieved of liability if he asserts and proves that the delay in performance is not due to reasons attributable to Y.
#
# </t2>
# </pair>
#
# <pair id="H18-29-5" label="N">
# <t1>
# Article 404: In the absence of a specific intention regarding a claim that bears interest, the interest rate shall be the statutory interest rate at the time when the interest first accrues.
# 2. The statutory interest rate shall be three percent per year.
# 3. Notwithstanding the provisions of the preceding paragraph, the statutory interest rate shall be set at three years per term, and shall fluctuate for each term in accordance with the provisions of the following paragraph, as provided for by the Ministry of Justice Ordinance.
# 4. The statutory interest rate for each period shall be the rate obtained by adding or subtracting from the statutory interest rate for the most recent period in which the statutory interest rate fluctuated pursuant to the provisions of this paragraph (hereinafter in this paragraph referred to as the "most recent fluctuation period") the rate equivalent to the difference between the base rate for the current period and the base rate (if the rate has a fraction of less than 1%, it shall be rounded down) to the statutory interest rate for the most recent fluctuation period.
# 5. The "base rate" prescribed in the preceding paragraph means the rate calculated by dividing the sum of the average interest rates on short-term loans for each month from January of the year six years prior to the year in which the first day of each period falls to December of the year before last (meaning the average interest rates on new loans made by banks in each such month (limited to loans with a loan period of less than one year)) by 60 (if the rate has a fraction of less than 0.1%, it shall be rounded down).
# Article 419: In the case of non-performance of an obligation for the delivery of money, the amount of damages shall be determined by the statutory interest rate. However, if the contracted interest rate exceeds the statutory interest rate, the contracted interest rate shall apply.
# 2: The creditor is not required to prove damages in the preceding paragraph.
# 3: In the case of damages in the first paragraph, the debtor cannot use force majeure as a defense.
# </t1>
# <t2>
# When X seeks damages at the rate of 5% per annum from the day after the due date for performance due to a delay in performance of the purchase price, he is not required to assert and prove the occurrence and amount of damages.
# </t2>
# </pair>
# <pair id="H18-32-5" label="N">
# <t1>
# Article 192: A person who, by a transactional act, peacefully and openly begins to possess movable property, acquires the right to exercise the same immediately if he is in good faith and free from negligence.
# </t1>
# <t2>
# A seller who cancels a movable property sales contract made under duress may demand the return of the movable property from the person who purchased the movable property from the buyer in good faith and without negligence before the cancellation, based on the right of ownership.
# </t2>
# </pair>
#
# </dataset>

# %% [markdown]
# **Parsing all the xml files**

# %%
import os
import xml.etree.ElementTree as ET
import pandas as pd

def parse_all_files(folder_path):
    data = []

    for filename in os.listdir(folder_path):
        if filename.endswith('.xml'):
            filepath = os.path.join(folder_path, filename)
            tree = ET.parse(filepath)
            root = tree.getroot()

            for pair in root.findall('pair'):
                pair_id = pair.attrib.get('id')
                label = pair.attrib.get('label')  # only in training set

                # t1 is the article (law text), t2 is the query/hypothesis
                article = pair.findtext('t1', default='').strip()
                query = pair.findtext('t2', default='').strip()

                sample = {
                    'id': pair_id,
                    'article': article,
                    'query': query
                }

                if label is not None:
                    sample['label'] = label

                data.append(sample)

    return pd.DataFrame(data)

# Example usage:
df = parse_all_files(train_folder)
print(df.head())
df.to_csv("/content/drive/MyDrive/Colab Notebooks/GenAIproject/parsed_legal_qa_trainenglish.csv", index=False)
# Out:
#         id                                            article  \
# 0  H18-1-1  Article 572: Even if the seller has made a spe...
# 1  H18-1-2  Article 565: The provisions of the preceding t...
# 2  H18-1-3  Article 568: A purchaser at an auction based o...
# 3  H18-2-1  Article 697. A person who begins to manage aff...
# 4  H18-2-2  Article 698: If a manager manages affairs in o...
#
#                                                query label
# 0  A special agreement exempting the seller from ...     Y
# 1  There is a time limit for pursuing liability f...     N
# 2  Since a forced auction is also a sale, the war...     N
# 3  Even if you repair a neighbor's fence to prote...     Y
# 4  If a person pushes away a person who is about ...     Y

# %%
import os
test_file_path = "/content/drive/MyDrive/Colab Notebooks/GenAIproject/test-for-task3/test-for-task3/TestData_en.xml"

print(f"Inspecting: {test_file_path}")

import xml.etree.ElementTree as ET

# Load and parse the file
tree = ET.parse(test_file_path)  # make sure sample_file has the correct path
root = tree.getroot()

# Print the full XML structure to inspect
ET.dump(root)
# Out:
# Inspecting: /content/drive/MyDrive/Colab Notebooks/GenAIproject/test-for-task3/test-for-task3/TestData_en.xml
# <dataset>
# <pair id="R06-01-A">
#
# <t2>
# When a petition for the commencement of curatorship is filed for a person who constantly lacks the capacity to appreciate a given situation due to mental disabilities, the family court may decide to establish a curatorship issue.
# </t2>
# </pair>
#
# <pair id="R06-01-E">
#
# <t2>
# If a person under adult guardianship purchases daily necessities without the consent of the adult guardian, the adult guardian may cancel the contract involving the purchase.
# </t2>
# </pair>
#
# <pair id="R06-01-I">
#
# <t2>
# When a petition for the commencement of assistantship is filed by someone other than the person in question, the family court cannot issue a ruling to commence assistance without the consent of the person concerned.
# </t2>
# </pair>
#
# <pair id="R06-01-O">
#
# <t2>
# If the assistant in court refuses to consent to an action that requires their consent despite there being no risk of harm to the interests of the person under assistance, the family court may, upon petition from the person under assistance, grant permission in place of the assistant's consent.
# </t2>
# </pair>
#
#
# <pair id="R06-03-A">
#
# <t2>
# When the other party makes a manifestation of intention to an agent, indicating that it is for the benefit of the principal, and the agent is authorized to receive such a manifestation of intention, the manifestation of intention is effective against the principal even if the agent does not explicitly indicate that they are receiving it on behalf of the principal.
# </t2>
# </pair>
#
# <pair id="R06-03-E">
#
# <t2>
# The authority of an agent is extinguished when the agent is placed under a decision to establish guardianship.
# </t2>
# </pair>
#
#
# <pair id="R06-03-I">
#
# <t2>
# If the effectiveness of a manifestation of intention made to an agent depends on the agent knowing certain circumstances, the determination of whether the fact exists will be made by either the agent or the principal, depending on the principal's choice.
# </t2>
# </pair>
#
# <pair id="R06-03-O">
#
# <t2>
# When the principal ratifies a contract made by a person without any authority, the contract becomes effective only for the future unless a particular intention is manifested.
# </t2>
# </pair>
#
# <pair id="R06-03-U">
#
# <t2>
# An agent by mandate cannot appoint a subagent without the principal's authorization unless there is a compelling reason.
# </t2>
# </pair>
#
#
# <pair id="R06-04-O">
#
# <t2>
# If an agent acts within the scope of their authority as agent with the purpose of benefiting a third party, and the other party could have ascertained this purpose, the act is considered as if it were performed by a person without any authority.
# </t2>
# </pair>
#
#
# <pair id="R06-05-E">
#
# <t2>
# The benefit of time cannot be waived if doing so would prejudice the interests of the other party.
# </t2>
# </pair>
#
#
# <pair id="R06-05-I">
#
# <t2>
# If it has already been established at the time of a juridical act that a condition precedent will not be fulfilled, the juridical act is invalid.
# </t2>
# </pair>
#
#
# <pair id="R06-05-O">
#
# <t2>
# A debtor who has caused collateral to be lost before the arrival of assigned time cannot claim the benefit of time.
# </t2>
# </pair>
#
#
# <pair id="R06-05-U">
#
# <t2>
# In a contract between A and B stating, "If B marries C, A will gift B a plot of land X owned by A," B cannot transfer their rights under the contract with A to a third party while the fulfillment of the condition remains uncertain.
# </t2>
# </pair>
#
# <pair id="R06-06-I">
#
# <t2>
# In calculating the acquisitive prescription period for ownership, the day possession begins is included in the period, even if the start of possession was not at twelve midnight.
# </t2>
# </pair>
#
#
# <pair id="R06-06-O">
#
# <t2>
# A person who exercises a property right other than ownership peacefully and openly with the intention to do so on the person's own behalf will acquire that right by prescription after the statutory period has passed.
# </t2>
# </pair>
#
#
# <pair id="R06-10-A">
#
# <t2>
# The owner of land may enter a neighboring residence near the boundary without the approval of the resident, as long as it is within the necessary scope for repairing structures near the boundary.
# </t2>
# </pair>
#
#
# <pair id="R06-10-E">
#
# <t2>
# The cost of maintaining boundary markers is borne equally by neighbors, regardless of the size of their respective lands.
# </t2>
# </pair>
#
#
# <pair id="R06-10-I">
#
# <t2>
# If a landowner cannot receive electricity without installing equipment on another's land, they may install such equipment within the necessary scope on that other land.
# </t2>
# </pair>
#
#
# <pair id="R06-10-O">
#
# <t2>
# If branches of bamboo or trees from neighboring land extend beyond the boundary, and the location of the owner of these plants is unknown, the landowner may cut the branches themselves.
# </t2>
# </pair>
#
#
# <pair id="R06-10-U">
#
# <t2>
# If a stream is blocked in a low-lying ground due to a natural disaster, the owner of higher land may, at a shared cost with the owner of the low-lying ground, carry out necessary work to remove the obstruction.
# </t2>
# </pair>
#
#
# <pair id="R06-11-A">
#
# <t2>
# Regarding Property X owned by the missing person A, suppose the court issues an administration order of ownerless land at the request of an interested person B and appoints C as the administrator of the ownerless land. The right to manage Property X belongs to both A and C.
# </t2>
# </pair>
#
#
# <pair id="R06-11-E">
#
# <t2>
# Regarding Property X owned by the missing person A, suppose the court issues an administration order of ownerless land at the request of an interested person B and appoints C as the administrator of the ownerless land. For lawsuits concerning Property X, C shall be either the plaintiff or the defendant.
# </t2>
# </pair>
#
#
# <pair id="R06-11-I">
#
# <t2>
# Regarding Property X owned by the missing person A, suppose the court issues an administration order of ownerless land at the request of an interested person B and appoints C as the administrator of the ownerless land. C must exercise their authority as the administrator of the ownerless land with the due care of a prudent manager on behalf of A, not B.
# </t2>
# </pair>
#
#
# <pair id="R06-11-O">
#
# <t2>
# Regarding Property X owned by the missing person A, suppose the court issues an administration order of ownerless land at the request of an interested person B and appoints C as the administrator of the ownerless land. B shall bear the necessary costs for managing Property X.
# </t2>
# </pair>
#
#
# <pair id="R06-11-U">
#
# <t2>
# Regarding Property X owned by the missing person A, suppose the court issues an administration order of ownerless land at the request of an interested person B and appoints C as the administrator of the ownerless land. If C obtains the court's permission, they may sell Property X.
# </t2>
# </pair>
#
#
# <pair id="R06-12-E">
#
# <t2>
# When the dominant land is co-owned by several individuals, the renewal of the prescription period does not become effective unless there are grounds for renewal of the extinctive prescription for all co-owners.
# </t2>
# </pair>
#
# <pair id="R06-12-I">
#
# <t2>
# A servitude, unless otherwise provided for the act of establishment, may serve as the purpose of a superficies right on the dominant land.
# </t2>
# </pair>
#
# <pair id="R06-12-U">
#
# <t2>
# If the owner of the servient land assumes the obligation, as stipulated in the act of establishment, to install structures at their own expense for the exercise of the servitude, then the specific successor of the servient land owner also assumes this obligation.
# </t2>
# </pair>
#
# <pair id="R06-13-I">
#
# <t2>
# When movable property installed by the lessee of a building is auctioned, the statutory lien on expenses for the common benefit, which secures the execution costs as a secured claim, takes priority over the statutory lien on the lease of real property for that movable property.
# </t2>
# </pair>
#
# <pair id="R06-14-A">
#
# <t2>
# A pledgee may not establish a pledge on the pledged property, securing their own debt with it as a secured claim, without the consent of the pledgor.
# </t2>
# </pair>
#
# <pair id="R06-14-E">
#
# <t2>
# The costs for managing real properties, which is the object of a real property pledge, shall be borne by the pledgee unless otherwise provided for the act of establishment.
# </t2>
# </pair>
#
# <pair id="R06-14-I">
#
# <t2>
# A pledgee of movable property may collect fruits produced from the pledged property and apply them to the payment of their claim before other obligees.
# </t2>
# </pair>
#
# <pair id="R06-14-O">
#
# <t2>
# A pledge does not secure compensation for damages caused by latent defects in the pledged property unless otherwise provided for the act of establishment.
# </t2>
# </pair>
#
#
# <pair id="R06-14-U">
#
# <t2>
# A pledgee of movable property may make use of the pledged property as necessary for its preservation without the consent of the pledgor.
# </t2>
# </pair>
#
# <pair id="R06-15-I">
#
# <t2>
# Suppose A has a loan claim X against B. If A and B agreed to prohibit the pledging of Claim X, and C, with knowledge of this prohibition, receives a pledge of Claim X from A, the pledge does not become effective.
# </t2>
# </pair>
#
#
# <pair id="R06-15-O">
#
# <t2>
# Suppose A has a loan claim X against B. If G receives a pledge of Claim X from A and is able to collect Claim X from B, G must make the collection in A's name.
# </t2>
# </pair>
#
# <pair id="R06-16-A">
#
# <t2>
# If Building Y existed on Land X at the time a mortgage was established on Land X, the mortgagee may auction Building Y along with Land X as part of the mortgage execution.
# </t2>
# </pair>
#
# <pair id="R06-16-O">
#
# <t2>
# A person using Building X, the object of the mortgage, under a lease that cannot be perfected against the mortgagee, must immediately deliver Building X to the purchaser if Building X is auctioned, even if they were using it before the start of the auction proceedings.
# </t2>
# </pair>
#
#
# <pair id="R06-16-U">
#
# <t2>
# For a registered lease, even if all mortgage holders who registered before the lease registration agree to the lease, this consent cannot be asserted against them unless it is also registered.
# </t2>
# </pair>
#
#
# <pair id="R06-17-A">
#
# <t2>
# The obligee cannot request performance in Japanese currency from the obligor for a monetary claim for which the amount of claim is designated in foreign currency.
# </t2>
# </pair>
#
# <pair id="R06-17-I">
#
# <t2>
# In cases where the claim's object is to be determined by a choice between two performances, if one of the performances becomes impossible without negligence of the person entitled to the right to choose, the claim's object is not specified to the other performance.
# </t2>
# </pair>
#
# <pair id="R06-17-O">
#
# <t2>
# If the obligor's interest payments are delayed for one year or more and the obligor does not pay such interests notwithstanding the demand by the obligee, the obligee may incorporate the delinquent interest into the principal.
# </t2>
# </pair>
#
#
# <pair id="R06-17-U">
#
# <t2>
# In an alternative obligation, unless another intention is manifested, the right to choose belongs to the obligor.
# </t2>
# </pair>
#
# <pair id="R06-18-I">
#
# <t2>
# If Painting X is lost due to grounds not attributable to either the seller of X or the buyer while the seller is responsible for a delay in their obligation, the buyer may request damages from the seller in place of performance of that obligation.
# </t2>
# </pair>
#
#
# <pair id="R06-19-A">
#
# <t2>
# Suppose A has a claim for the sale price of 10 million yen against B based on a purchase and sale contract with B, and B performs a loan obligation of 5 million yen to C. In this case, if A files an action against C as the defendant, seeking rescission of the performance and a payment of 5 million yen to A, and this claim is granted, then C's claim against B reverts to its original state upon the finalization of the judgment.
# </t2>
# </pair>
#
#
# <pair id="R06-19-E">
#
# <t2>
# Suppose A has a claim for the sale price of 10 million yen against B based on a purchase and sale contract with B. B donates movable property Y owned by B to G, who then donates Y to H, and H then donates Y to I, with delivery occurring each time. In this case, for A's claim against I seeking the rescission of the donation between B and G and the return of Y to A to be granted, all parties G, H, and I must have had knowledge that the donation between B and G would harm obligees at the time each received the gift.
# </t2>
# </pair>
#
#
# <pair id="R06-20-A">
#
# <t2>
# If A and B hold a joint and several claim of 1 million yen against C, and A makes a request for performance to C, then the prescription for B's claim is postponed for six months from that time.
# </t2>
# </pair>
#
#
# <pair id="R06-20-E">
#
# <t2>
# An indivisible obligation is established when the purpose of the obligation is indivisible by nature or by the parties' manifested intention.
# </t2>
# </pair>
#
# <pair id="R06-20-O">
#
# <t2>
# If A and B have each agreed, under a special provision, to act as guarantors for C's 1 million yen obligation to D, bearing an equal share of the obligation, and each independently liable for the full amount, then A, upon performing 200,000 yen, may not seek reimbursement of 100,000 yen from B.
# </t2>
# </pair>
#
# <pair id="R06-20-U">
#
# <t2>
# If A and B have a joint and several obligation of 1 million yen to C, with equal shares of the obligation, and A holds a claim of 800,000 yen against C, then if C demands 1 million yen from B, B may set off C's claim against A to the extent of 500,000 yen, using A's claim against C as the active set-off claim and C's claim against A as the passive set-off claim.
# </t2>
# </pair>
#
# <pair id="R06-21-A">
#
# <t2>
# Even if the obligor of a fungible obligation delivers another's property as payment and the obligee cannot acquire ownership of it, if the obligee consumes the property in good faith, the payment remains valid.
# </t2>
# </pair>
#
# <pair id="R06-21-I">
#
# <t2>
# When an obligor must pay interest and expenses in addition to the principal for a single obligation, if the obligor performs an amount insufficient to extinguish the entire obligation, this performance shall, in the absence of any other agreement between the parties, be appropriated sequentially to expenses, interest, and then principal.
# </t2>
# </pair>
#
# <pair id="R06-22-A">
#
# <t2>
# Suppose there has been an assumption of obligee B's X obligation to obligee A, with C as the guarantor. If this assumption is an assumption of obligation not releasing an obligor, the X obligation is extinguished upon a novation between A and C.
# </t2>
# </pair>
#
# <pair id="R06-22-E">
#
# <t2>
# Suppose there has been an assumption of obligee B's X obligation to obligee A, with C as the guarantor. If this assumption is an assumption of obligation releasing an old obligor, and B can set off Y claim against A as the active claim and the claim for the X obligation as the passive claim, then C may refuse performance of the obligation to A to the extent that the X obligation should be extinguished by the set-off.
# </t2>
# </pair>
#
#
# <pair id="R06-22-I">
#
# <t2>
# Suppose there has been an assumption of obligee B's X obligation to obligee A, with C as the guarantor. If this assumption is an assumption of obligation not releasing an obligor entered into by A and C against B's wishes, it does not become effective.
# </t2>
# </pair>
#
# <pair id="R06-22-O">
#
# <t2>
# Suppose there has been an assumption of obligee B's X obligation to obligee A, with C as the guarantor. If this assumption is an assumption of obligation releasing an old obligor, A cannot transfer the mortgage established by C as security for the X obligation to C's obligation.
# </t2>
# </pair>
#
#
# <pair id="R06-22-U">
#
# <t2>
# Suppose there has been an assumption of obligee B's X obligation to obligee A, with C as the guarantor. If this assumption is an assumption of obligation releasing an old obligor, even if C performs the obligation borne, C does not acquire a right to reimbursement against B unless there is another agreement between B and C.
# </t2>
# </pair>
#
#
# <pair id="R06-23-I">
#
# <t2>
# Suppose A and B have joint and several claims of 600,000 yen against C, with an equal internal ratio. If A releases C from the obligation, B may request payment only to the extent of 300,000 yen.
# </t2>
# </pair>
#
# <pair id="R06-24-A">
#
# <t2>
# If A makes an offer to B, a person at a distance, and B issues a notice of acceptance, then even if B subsequently issues a notice of revocation of acceptance and it arrives at A before the notice of acceptance, the contract is established.
# </t2>
# </pair>
#
#
# <pair id="R06-24-E">
#
# <t2>
# If A makes an offer to B, a person at a distance, and after the notice of the offer reaches B, A dies, and B learns of A's death before issuing a notice of acceptance, the contract will not be established, even if B subsequently accepts.
# </t2>
# </pair>
#
# <pair id="R06-24-I">
#
# <t2>
# If A makes an offer to B, a person in conversation, without setting a period for acceptance, A may revoke the offer as long as the conversation continues.
# </t2>
# </pair>
#
#
# <pair id="R06-24-O">
#
# <t2>
# If in A's offer to B it is stated that the contract will be established upon B beginning manufacture of the subject matter without requiring a notice of acceptance, the contract will not be established until A learns of the fact that B has begun manufacture, even if B has started the production of the subject matter.
# </t2>
# </pair>
#
# <pair id="R06-24-U">
#
# <t2>
# If A makes an offer to B, a person at a distance, setting a period for acceptance, and B's notice of acceptance arrives after the expiration of that period, the contract is established as if the acceptance had arrived within the period if A knew that, under normal circumstances, the notice would have arrived within the period and fails to notify B without delay of late arrival's notice.
# </t2>
# </pair>
#
# <pair id="R06-26-A">
#
# <t2>
# Suppose A enters into a contract to make a gift of a painting owned by A with a burden, item X, to B. Even without the delivery of X from A to B, the contract becomes effective.
# </t2>
# </pair>
#
# <pair id="R06-26-E">
#
# <t2>
# Suppose A enters into a contract to make a gift of a painting owned by A with a burden, item X, to B. If this contract was not made in writing, B may cancel the contract before fulfilling their obligations, even after receiving delivery of X from A.
# </t2>
# </pair>
#
# <pair id="R06-26-I">
#
# <t2>
# Suppose A enters into a contract to make a gift of a painting owned by A with a burden, item X, to B. If this contract was not made in writing, A may cancel the contract before delivering X to B, even if B has fulfilled all of their obligations.
# </t2>
# </pair>
#
# <pair id="R06-27-A">
#
# <t2>
# If the lessee has incurred beneficial expenses with respect to the leased building, the lessee may immediately demand reimbursement from the lessor.
# </t2>
# </pair>
#
# <pair id="R06-28-E">
#
# <t2>
# Suppose that the party ordering the work, A, contracted with the contractor, B, to build a building X. If the quality of the completed and delivered building X does not conform to the terms of the contract, and B was in good faith and without gross negligence at the time of delivery, A must file an action within one year from the time they became aware of the non-conformity in order to claim damages from B for that non-conformity.
# </t2>
# </pair>
#
# <pair id="R06-28-O">
#
# <t2>
# Suppose that the party ordering the work, A, contracted with the contractor, B, to build a building X. If the contract for work is cancelled due to B's non-performance during the course of construction, and A receives benefits from any divisible portion of the performance, B may demand remuneration in proportion to the benefit that A receives.
# </t2>
# </pair>
#
#
# <pair id="R06-29-A">
#
# <t2>
# A gratuitous bailee may cancel the bailment contract, even if it was made in writing, up until the bailee receives the bailed goods.
# </t2>
# </pair>
#
#
# <pair id="R06-29-E">
#
# <t2>
# If the bailee has incurred an obligation necessary for keeping the bailed goods, the bailee may, only if the bailment is gratuitous, request that the bailor perform this obligation on the bailee's behalf.
# </t2>
# </pair>
#
# <pair id="R06-29-I">
#
# <t2>
# The bailee, regardless of whether or not there is a reward, has a duty to keep the bailed goods with the same care a person would exercise for their own property.
# </t2>
# </pair>
#
#
# <pair id="R06-29-U">
#
# <t2>
# If the nature of the bailed goods causes damage to the bailee, the bailor must compensate for the damage unless the bailor was unaware of the nature of the goods without negligence, or if the bailee already knew of this nature.
# </t2>
# </pair>
#
# <pair id="R06-30-E">
#
# <t2>
# If the administrator performed benevolent intervention in another's affairs in order to allow a principal to escape imminent danger to the principal's person, and the administrator acted intentionally or with negligence, the administrator is liable to compensate for damages caused by this intervention.
# </t2>
# </pair>
#
# <pair id="R06-30-I">
#
# <t2>
# If an administrator is able to conjecture the principal's intention, they must perform the benevolent intervention in another's affairs according to that intention.
# </t2>
# </pair>
#
# <pair id="R06-30-O">
#
# <t2>
# If the administrator has used funds that are due for delivery to the principal for their own benefit, they must pay interest starting from the date of use.
# </t2>
# </pair>
#
# <pair id="R06-30-U">
#
# <t2>
# If expenses are necessary to perform the benevolent intervention in another's affairs, the principal must make an advance payment at the administrator's request.
# </t2>
# </pair>
#
# <pair id="R06-31-U">
#
# <t2>
# If a defect in the installation of a structure on land causes damage to another person, and the possessor of that structure, who is liable to compensate for the damage, has no financial resources, the owner of the structure also bears liability for compensating the damage.
# </t2>
# </pair>
#
# <pair id="R06-37-A">
#
# <t2>
# The agent without specifically defined authority has the authority to perform acts of preservation.
# </t2>
# </pair>
#
#
# <pair id="R06-37-E">
#
# <t2>
# Even if the lessor intends to perform acts necessary for the preservation of the leased property, the lessee may refuse if such acts would prevent the lessee from achieving the purpose for which the lease was made.
# </t2>
# </pair>
#
# <pair id="R06-37-I">
#
# <t2>
# A co-owner may perform acts of preservation on co-owned property without obtaining the consent of other co-owners, even if the price of their ownership share does not reach a majority.
# </t2>
# </pair>
#
#
# <pair id="R06-37-U">
#
# <t2>
# Any person who has a claim against the owner of movable property arising from the preservation of that property has the right to receive payment of their claim in preference to other obligees with respect to that property.
# </t2>
# </pair>
#
# </dataset>

# %%
import xml.etree.ElementTree as ET
import pandas as pd

def parse_test_file(file_path):
    data = []

    tree = ET.parse(file_path)
    root = tree.getroot()

    for pair in root.findall('pair'):
        pair_id = pair.attrib.get('id')

        article = pair.findtext('t1', default='').strip()
        query = pair.findtext('t2', default='').strip()

        data.append({
            'id': pair_id,
            'article': article,
            'query': query
        })

    return pd.DataFrame(data)

# Example usage:
test_file_path = "/content/drive/MyDrive/Colab Notebooks/GenAIproject/test-for-task3/test-for-task3/TestData_en.xml"
df_test = parse_test_file(test_file_path)
print(df_test.head())

# Save to CSV if needed
df_test.to_csv("/content/drive/MyDrive/Colab Notebooks/GenAIproject/parsed_legal_qa_testenglish.csv", index=False)
# Out:
#          id article                                              query
# 0  R06-01-A          When a petition for the commencement of curato...
# 1  R06-01-E          If a person under adult guardianship purchases...
# 2  R06-01-I          When a petition for the commencement of assist...
# 3  R06-01-O          If the assistant in court refuses to consent t...
# 4  R06-03-A          When the other party makes a manifestation of ...

# %% [markdown]
# **Parsing the code law Text Files**

# %%
civil_code_file = os.path.join(text_folder, "civil_code_jp-1to724-2.txt")

# Open and print a portion of the file
with open(civil_code_file, 'r', encoding='utf-8') as file:
    lines = file.readlines()

print(f"Total lines: {len(lines)}")
print("\n--- First 30 lines ---\n")
for line in lines[:30]:
    print(line.strip())
# Out:
# Total lines: 2866
#
# --- First 30 lines ---
#
# Civil Code (Parts 1, 2, and 3)
# Part 1: General Provisions
# Chapter 1: General Provisions
# (Basic Principles)
# Article 1: Private rights must conform to the public welfare.
# 2: Rights must be exercised and obligations must be performed in good faith.
# 3: Abuse of rights is not permitted.
# (Standards for interpretation)
# Article 2: This Act must be interpreted in accordance with the dignity of the individual and the essential equality of the sexes.
# Chapter 2: Persons
# Section 1: Capacity to have rights
# Article 3: The enjoyment of private rights begins at birth.
# 2: Foreigners shall enjoy private rights, except in cases prohibited by law or treaty.
# Section 2: Capacity to make decisions
# Article 3-2: If a party to a legal act does not have capacity to make decisions at the time of expressing his or her intention, the legal act is invalid.
# Section 3: Capacity to make decisions
# (Adulthood)
# Article 4: A person becomes an adult at the age of 20.
# (Legal acts of minors)
# Article 5: In order for a minor to perform a legal act, the consent of his/her legal representative must be obtained. However, this does not apply to legal acts that merely acquire rights or relieve obligations.
# 2: Any legal act that violates the provisions of the preceding paragraph may be revoked.
# 3: Notwithstanding the provisions of paragraph 1, the minor may freely dispose of property that the legal representative has permitted the disposal of with a specified purpose, within the scope of that purpose. The same applies when disposing of property that has been permitted the disposal of without specifying a purpose.
# (Business permission for minors)
# Article 6: A minor who has been permitted to carry out one or more types of business has the same capacity to act as an adult with regard to that business.
# 2: In the case of the preceding paragraph, if there is a reason that the minor is unable to carry out the business, the legal representative may revoke or restrict the permission in accordance with the provisions of Part 4 (Relatives).
# (Judgment for commencement of guardianship)
# Article 7: In the case of a person who is in a constant state of lacking the capacity to discern facts and circumstances due to a mental disability, the family court may make a judgment for the commencement of guardianship at the request of the person himself/herself, his/her spouse, a relative within the fourth degree of kinship, a guardian of a minor, a supervisor of a guardian of a minor, a curator, a supervisor of a curator, an assistant, an assistant supervisor, or a public prosecutor.
# (Adult wards and adult guardians)
# Article 8: A person who has been subject to a judgment for the commencement of guardianship becomes an adult ward, and an adult guardian is assigned to him/her.
# (Legal acts of adult wards)

# %%
import os
import re

civil_code_file = os.path.join(text_folder, "civil_code_jp-1to724-2.txt")

with open(civil_code_file, 'r', encoding='utf-8') as file:
    lines = file.readlines()

article_dict = {}
current_article = None
article_text = []

for line in lines:
    line = line.strip()
    if not line:
        continue  # skip empty lines

    # Start of a new article
    article_match = re.match(r'Article\s+(\d+[-\d+]*)\:', line)
    if article_match:
        # Save the previous article before starting a new one
        if current_article:
            article_dict[current_article] = ' '.join(article_text).strip()

        current_article = f"Article {article_match.group(1)}"
        article_text = [line.split(":", 1)[1].strip()]  # get the first line of the article
    elif re.match(r'^\d+:', line):
        # Sub-clause of the current article
        clause_text = line.split(":", 1)[1].strip()
        article_text.append(clause_text)
    elif current_article:
        # Continuation of the current article (often a new paragraph)
        article_text.append(line)

# Save the last article
if current_article:
    article_dict[current_article] = ' '.join(article_text).strip()

print(f"Total articles parsed: {len(article_dict)}")
print("\nSample:\n")
for k in list(article_dict.keys())[:5]:
    print(k, "→", article_dict[k])
# Out:
# Total articles parsed: 476
#
# Sample:
#
# Article 1 → Private rights must conform to the public welfare. Rights must be exercised and obligations must be performed in good faith. Abuse of rights is not permitted. (Standards for interpretation)
# Article 2 → This Act must be interpreted in accordance with the dignity of the individual and the essential equality of the sexes. Chapter 2: Persons Section 1: Capacity to have rights
# Article 3 → The enjoyment of private rights begins at birth. Foreigners shall enjoy private rights, except in cases prohibited by law or treaty. Section 2: Capacity to make decisions
# Article 3-2 → If a party to a legal act does not have capacity to make decisions at the time of expressing his or her intention, the legal act is invalid. Section 3: Capacity to make decisions (Adulthood)
# Article 4 → A person becomes an adult at the age of 20. (Legal acts of minors)

# %%
import csv

output_path_csv = "/content/drive/MyDrive/Colab Notebooks/GenAIproject/parsed_civil_code.csv"
with open(output_path_csv, "w", newline='', encoding="utf-8") as csvfile:
    writer = csv.writer(csvfile)
    writer.writerow(["Article", "Text"])
    for article_id, text in article_dict.items():
        writer.writerow([article_id, text])

print(f"Saved parsed articles to {output_path_csv}")
# Out:
# Saved parsed articles to /content/drive/MyDrive/Colab Notebooks/GenAIproject/parsed_civil_code.csv

# %% [markdown]
# # **Fine Tuning for legal Entailment task**

# %% [markdown]
# Fine tuning the complete model

# %%
import pandas as pd
from sklearn.model_selection import train_test_split

# Load the dataset
df = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/GenAIproject/parsed_legal_qa_trainenglish.csv")

# Split into 80% train and 20% validation
train_df, val_df = train_test_split(df, test_size=0.2, random_state=42, stratify=df["label"])

# %%
from sentence_transformers import SentenceTransformer, models

# Load transformer
word_embedding_model = models.Transformer("nlpaueb/legal-bert-base-uncased")

# Add pooling layer
pooling_model = models.Pooling(
    word_embedding_model.get_word_embedding_dimension(),
    pooling_mode='mean'
)

# SentenceTransformer model
embedding_model = SentenceTransformer(modules=[word_embedding_model, pooling_model])
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(

# %%
from sentence_transformers import losses

train_loss = losses.CosineSimilarityLoss(model=embedding_model)

# %%
pip install datasets
# Out:
# Requirement already satisfied: datasets in /usr/local/lib/python3.11/dist-packages (3.5.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from datasets) (3.18.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from datasets) (2.0.2)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.11/dist-packages (from datasets) (18.1.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.11/dist-packages (from datasets) (0.3.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from datasets) (2.2.2)
# Requirement already satisfied: requests>=2.32.2 in /usr/local/lib/python3.11/dist-packages (from datasets) (2.32.3)
# Requirement already satisfied: tqdm>=4.66.3 in /usr/local/lib/python3.11/dist-packages (from datasets) (4.67.1)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.11/dist-packages (from datasets) (3.5.0)
# Requirement already satisfied: multiprocess<0.70.17 in /usr/local/lib/python3.11/dist-packages (from datasets) (0.70.16)
# Requirement already satisfied: fsspec<=2025.3.0,>=2023.1.0 in /usr/local/lib/python3.11/dist-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (2025.3.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.11/dist-packages (from datasets) (3.11.15)
# Requirement already satisfied: huggingface-hub>=0.24.0 in /usr/local/lib/python3.11/dist-packages (from datasets) (0.30.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from datasets) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from datasets) (6.0.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (1.6.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (6.4.3)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (1.20.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.24.0->datasets) (4.13.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets) (2025.4.26)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.17.0)

# %%
from sentence_transformers import InputExample
from datasets import IterableDataset
from sentence_transformers import InputExample, SentencesDataset
from datasets import Dataset
# Step 1: Clean and preprocess the data
train_df = train_df.dropna(subset=["article", "query", "label"])
train_df['label'] = train_df['label'].map({'Y': 1, 'N': 0})

# Step 2: Create InputExample objects for the Sentence-Transformers Trainer
train_examples = [
    InputExample(texts=[row['query'], row['article']], label=float(row['label']))
    for _, row in train_df.iterrows()
]

# Now use SentencesDataset
#train_dataset = SentencesDataset(train_examples, model=embedding_model)
# Convert SentencesDataset to Hugging Face Dataset
#hf_dataset = Dataset.from_dict({
  #  "texts": [[ex.texts[0], ex.texts[1]] for ex in train_examples],
 #   "label": [ex.label for ex in train_examples]
#})
# Step 2: Convert data to the correct Hugging Face Dataset format with separate columns for query and article
hf_dataset = Dataset.from_dict({
    "query": train_df["query"].tolist(),
    "article": train_df["article"].tolist(),
    "label": train_df["label"].tolist()
})


# Now, train_dataset is iterable and you can pass it to your trainer

# %%
from sentence_transformers.evaluation import EmbeddingSimilarityEvaluator
from sklearn.metrics import accuracy_score, f1_score

# Prepare your validation dataset (assume your validation dataset has 'query', 'article', and 'label')
# Convert 'label' into 0 (No) and 1 (Yes) for binary classification

# For example, label might already be in a "Yes"/"No" format, so just encode it
val_labels = [1 if label == 'Y' else 0 for label in val_df["label"]]

# Create the ClassificationEvaluator
evaluator = EmbeddingSimilarityEvaluator(
    sentences1=val_df["query"],   # Use the 'query' as sentence1
    sentences2=val_df["article"], # Use the 'article' as sentence2
    scores=val_labels,
    main_similarity="cosine"
)

# %%
from sentence_transformers.training_args import SentenceTransformerTrainingArguments
 # Define the training arguments
args = SentenceTransformerTrainingArguments(
output_dir="/content/drive/MyDrive/Colab Notebooks/GenAIproject/output/base_embedding_model",
num_train_epochs=1,
per_device_train_batch_size=4,
per_device_eval_batch_size=4,
warmup_steps=100,
fp16=True,
eval_steps=100,
logging_steps=100,
report_to="none"
)

# %%
# !pip install -U "sentence-transformers[train]"
# Out:
# Requirement already satisfied: sentence-transformers[train] in /usr/local/lib/python3.11/dist-packages (3.4.1)
# Collecting sentence-transformers[train]
#   Downloading sentence_transformers-4.1.0-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: transformers<5.0.0,>=4.41.0 in /usr/local/lib/python3.11/dist-packages (from sentence-transformers[train]) (4.51.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from sentence-transformers[train]) (4.67.1)
# Requirement already satisfied: torch>=1.11.0 in /usr/local/lib/python3.11/dist-packages (from sentence-transformers[train]) (2.6.0+cu124)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.11/dist-packages (from sentence-transformers[train]) (1.6.1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from sentence-transformers[train]) (1.15.2)
# Requirement already satisfied: huggingface-hub>=0.20.0 in /usr/local/lib/python3.11/dist-packages (from sentence-transformers[train]) (0.30.2)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.11/dist-packages (from sentence-transformers[train]) (11.2.1)
# Requirement already satisfied: typing_extensions>=4.5.0 in /usr/local/lib/python3.11/dist-packages (from sentence-transformers[train]) (4.13.2)
# Requirement already satisfied: datasets in /usr/local/lib/python3.11/dist-packages (from sentence-transformers[train]) (3.5.1)
# Requirement already satisfied: accelerate>=0.20.3 in /usr/local/lib/python3.11/dist-packages (from sentence-transformers[train]) (1.6.0)
# Requirement already satisfied: numpy<3.0.0,>=1.17 in /usr/local/lib/python3.11/dist-packages (from accelerate>=0.20.3->sentence-transformers[train]) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from accelerate>=0.20.3->sentence-transformers[train]) (24.2)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from accelerate>=0.20.3->sentence-transformers[train]) (5.9.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.11/dist-packages (from accelerate>=0.20.3->sentence-transformers[train]) (6.0.2)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.11/dist-packages (from accelerate>=0.20.3->sentence-transformers[train]) (0.5.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers[train]) (3.18.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers[train]) (2025.3.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers[train]) (2.32.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers[train]) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers[train]) (3.1.6)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch>=1.11.0->sentence-transformers[train])
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch>=1.11.0->sentence-transformers[train])
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch>=1.11.0->sentence-transformers[train])
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch>=1.11.0->sentence-transformers[train])
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch>=1.11.0->sentence-transformers[train])
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch>=1.11.0->sentence-transformers[train])
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch>=1.11.0->sentence-transformers[train])
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch>=1.11.0->sentence-transformers[train])
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch>=1.11.0->sentence-transformers[train])
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers[train]) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers[train]) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers[train]) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch>=1.11.0->sentence-transformers[train])
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers[train]) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers[train]) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=1.11.0->sentence-transformers[train]) (1.3.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers[train]) (2024.11.6)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.11/dist-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers[train]) (0.21.1)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.11/dist-packages (from datasets->sentence-transformers[train]) (18.1.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.11/dist-packages (from datasets->sentence-transformers[train]) (0.3.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from datasets->sentence-transformers[train]) (2.2.2)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.11/dist-packages (from datasets->sentence-transformers[train]) (3.5.0)
# Requirement already satisfied: multiprocess<0.70.17 in /usr/local/lib/python3.11/dist-packages (from datasets->sentence-transformers[train]) (0.70.16)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.11/dist-packages (from datasets->sentence-transformers[train]) (3.11.15)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn->sentence-transformers[train]) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn->sentence-transformers[train]) (3.6.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets->sentence-transformers[train]) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets->sentence-transformers[train]) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets->sentence-transformers[train]) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets->sentence-transformers[train]) (1.6.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets->sentence-transformers[train]) (6.4.3)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets->sentence-transformers[train]) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets->sentence-transformers[train]) (1.20.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers[train]) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers[train]) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers[train]) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers[train]) (2025.4.26)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=1.11.0->sentence-transformers[train]) (3.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets->sentence-transformers[train]) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets->sentence-transformers[train]) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets->sentence-transformers[train]) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas->datasets->sentence-transformers[train]) (1.17.0)
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 2.3 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 97.9 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 77.7 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 46.6 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 752.7 kB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 1.5 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 12.6 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 8.7 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 8.5 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 89.5 MB/s eta 0:00:00
# Downloading sentence_transformers-4.1.0-py3-none-any.whl (345 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 345.7/345.7 kB 25.2 MB/s eta 0:00:00
# Installing collected packages: nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, sentence-transformers
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
#   Attempting uninstall: sentence-transformers
#     Found existing installation: sentence-transformers 3.4.1
#     Uninstalling sentence-transformers-3.4.1:
#       Successfully uninstalled sentence-transformers-3.4.1
# Successfully installed nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127 sentence-transformers-4.1.0

# %%
# 10. Start training
import os
os.environ["WANDB_DISABLED"] = "true"

# %%
pip install wandb
# Out:
# Requirement already satisfied: wandb in /usr/local/lib/python3.11/dist-packages (0.19.10)
# Requirement already satisfied: click!=8.0.0,>=7.1 in /usr/local/lib/python3.11/dist-packages (from wandb) (8.1.8)
# Requirement already satisfied: docker-pycreds>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from wandb) (0.4.0)
# Requirement already satisfied: gitpython!=3.1.29,>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from wandb) (3.1.44)
# Requirement already satisfied: platformdirs in /usr/local/lib/python3.11/dist-packages (from wandb) (4.3.7)
# Requirement already satisfied: protobuf!=4.21.0,!=5.28.0,<7,>=3.19.0 in /usr/local/lib/python3.11/dist-packages (from wandb) (5.29.4)
# Requirement already satisfied: psutil>=5.0.0 in /usr/local/lib/python3.11/dist-packages (from wandb) (5.9.5)
# Requirement already satisfied: pydantic<3 in /usr/local/lib/python3.11/dist-packages (from wandb) (2.11.3)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.11/dist-packages (from wandb) (6.0.2)
# Requirement already satisfied: requests<3,>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from wandb) (2.32.3)
# Requirement already satisfied: sentry-sdk>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from wandb) (2.27.0)
# Requirement already satisfied: setproctitle in /usr/local/lib/python3.11/dist-packages (from wandb) (1.3.6)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from wandb) (75.2.0)
# Requirement already satisfied: typing-extensions<5,>=4.4 in /usr/local/lib/python3.11/dist-packages (from wandb) (4.13.2)
# Requirement already satisfied: six>=1.4.0 in /usr/local/lib/python3.11/dist-packages (from docker-pycreds>=0.4.0->wandb) (1.17.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.11/dist-packages (from gitpython!=3.1.29,>=1.0.0->wandb) (4.0.12)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3->wandb) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.1 in /usr/local/lib/python3.11/dist-packages (from pydantic<3->wandb) (2.33.1)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3->wandb) (0.4.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.0.0->wandb) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.0.0->wandb) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.0.0->wandb) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.0.0->wandb) (2025.4.26)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.11/dist-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.29,>=1.0.0->wandb) (5.0.2)

# %%
from sentence_transformers.trainer import SentenceTransformerTrainer
 # Train embedding model
trainer = SentenceTransformerTrainer(
 model=embedding_model,
 args=args,
 train_dataset=hf_dataset,
 loss=train_loss,
 evaluator=evaluator
 )
trainer.train()
# Out:
# Computing widget examples:   0%|          | 0/1 [00:00<?, ?example/s]
#     <div>
#
#       <progress value='240' max='240' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [240/240 49:59, Epoch 1/1]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>100</td>
#       <td>0.295400</td>
#     </tr>
#     <tr>
#       <td>200</td>
#       <td>0.280700</td>
#     </tr>
#   </tbody>
# </table><p>
# TrainOutput(global_step=240, training_loss=0.2829511602719625, metrics={'train_runtime': 3016.31, 'train_samples_per_second': 0.318, 'train_steps_per_second': 0.08, 'total_flos': 0.0, 'train_loss': 0.2829511602719625, 'epoch': 1.0})

# %%
# loading the saved model
from sentence_transformers import SentenceTransformer

embedding_model = SentenceTransformer("/content/drive/MyDrive/Colab Notebooks/GenAIproject/output/base_embedding_model//checkpoint-240")
# Out:
# WARNING:sentence_transformers.SentenceTransformer:You try to use a model that was created with version 4.1.0, however, your version is 3.4.1. This might cause unexpected behavior or errors. In that case, try to update to the latest version.

# %%
# Show the first 10 rows of the raw validation data
print(val_df[["query", "article", "label"]].head(10))

# Optionally, check unique label values to see what exactly is present
print("Unique label values in val_df:", val_df["label"].unique())
# Out:
#                                                   query  \
# 276   In a contract that involves the completion of ...
# 800   When the due date of the claim that is the obj...
# 226   When a debtor who is solely responsible for mo...
# 1088  In a lawsuit in which an agent claims the paym...
# 1149  Concurrent debt assumption shall be validly es...
# 666   The validity of a contract for the benefit of ...
# 1170  A has concluded a loan contract with B to allo...
# 549   When a defect in the object of work was caused...
# 674   The administrator appointed by the absentee ma...
# 0     A special agreement exempting the seller from ...
#
#                                                 article label
# 276   Article 637: In the case prescribed in the mai...     N
# 800   Article 366: A pledgee may directly collect th...     N
# 226   Article 147: In the event of any of the follow...     N
# 1088  Article 632: A contract comes into effect when...     N
# 1149  Article 470: The assumer of a concurrent debt ...     Y
# 666   (Contracts for the benefit of a third party)\n...     Y
# 1170  Article 594 The borrower must use and profit f...     N
# 549   Article 636: When a contractor delivers to a c...     N
# 674   (Administrator's authority)\nArticle 28: When ...     N
# 0     Article 572: Even if the seller has made a spe...     Y
# Unique label values in val_df: ['N' 'Y']

# %%
from sentence_transformers.evaluation import EmbeddingSimilarityEvaluator

# Ensure the DataFrame index is reset (to avoid KeyError issues)
val_df = val_df.reset_index(drop=True)
val_df['label'] = val_df['label'].map({'Y': 1, 'N': 0})
# Convert labels to float list (if already numeric 0/1)
val_labels = val_df["label"].astype(float).tolist()

# Ensure sentences are passed as lists of strings
queries = val_df["query"].astype(str).tolist()
articles = val_df["article"].astype(str).tolist()

# Create the evaluator
evaluator = EmbeddingSimilarityEvaluator(
    sentences1=queries,       # Hypotheses
    sentences2=articles,     # Articles
    scores=val_labels,       # Ground-truth entailment (1 or 0)
    main_similarity="cosine" # Similarity metric
)
import pandas as pd

val_display_df = pd.DataFrame({
    "query": queries,
    "article": articles,
    "label": val_labels
})

# Show the first few rows
print(val_display_df.head(10))
# Out:
#                                                query  \
# 0  In a contract that involves the completion of ...
# 1  When the due date of the claim that is the obj...
# 2  When a debtor who is solely responsible for mo...
# 3  In a lawsuit in which an agent claims the paym...
# 4  Concurrent debt assumption shall be validly es...
# 5  The validity of a contract for the benefit of ...
# 6  A has concluded a loan contract with B to allo...
# 7  When a defect in the object of work was caused...
# 8  The administrator appointed by the absentee ma...
# 9  A special agreement exempting the seller from ...
#
#                                              article  label
# 0  Article 637: In the case prescribed in the mai...    0.0
# 1  Article 366: A pledgee may directly collect th...    0.0
# 2  Article 147: In the event of any of the follow...    0.0
# 3  Article 632: A contract comes into effect when...    0.0
# 4  Article 470: The assumer of a concurrent debt ...    1.0
# 5  (Contracts for the benefit of a third party)\n...    1.0
# 6  Article 594 The borrower must use and profit f...    0.0
# 7  Article 636: When a contractor delivers to a c...    0.0
# 8  (Administrator's authority)\nArticle 28: When ...    0.0
# 9  Article 572: Even if the seller has made a spe...    1.0

# %%
evaluator(embedding_model)
# Out:
# {'pearson_cosine': np.float64(0.27215176540383806),
#  'spearman_cosine': np.float64(0.26044746396146756)}

# %% [markdown]
# **Resuming the training for more epochs**

# %%
from sentence_transformers.trainer import SentenceTransformerTrainer
from sentence_transformers.training_args import SentenceTransformerTrainingArguments

from datasets import IterableDataset
# Step 1: Load the model from your checkpoint
embedding_model = SentenceTransformer("/content/drive/MyDrive/Colab Notebooks/GenAIproject/output/base_embedding_model/checkpoint-240")

# Step 2: Define the training arguments (run for 2 more epochs)
args = SentenceTransformerTrainingArguments(
    output_dir="/content/drive/MyDrive/Colab Notebooks/GenAIproject/output/base_embedding_model",
    num_train_epochs=2,
    per_device_train_batch_size=4,
    per_device_eval_batch_size=4,
    warmup_steps=100,
    fp16=True,
    eval_steps=100,                  # Run evaluation every 10 steps
    logging_steps=100,               # Log training metrics every 10 steps
    eval_strategy="steps",    # Required to evaluate during training
    logging_dir="./logs",
    save_strategy="epoch",          # Save checkpoint after each epoch
    report_to="none"                # Disable logging to external tools
)

train_loss = losses.CosineSimilarityLoss(model=embedding_model)

# Step 4: Initialize the trainer
trainer = SentenceTransformerTrainer(
    model=embedding_model,
    args=args,
    train_dataset=hf_dataset,
    loss=train_loss,
    evaluator=evaluator
)

# Step 5: Resume training
trainer.train(resume_from_checkpoint=True)
# Out:
# Computing widget examples:   0%|          | 0/1 [00:00<?, ?example/s]
#     <div>
#
#       <progress value='480' max='480' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [480/480 56:48, Epoch 2/2]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Pearson Cosine</th>
#       <th>Spearman Cosine</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>300</td>
#       <td>0.242300</td>
#       <td>No log</td>
#       <td>0.199302</td>
#       <td>0.213411</td>
#     </tr>
#     <tr>
#       <td>400</td>
#       <td>0.224400</td>
#       <td>No log</td>
#       <td>0.310168</td>
#       <td>0.296778</td>
#     </tr>
#   </tbody>
# </table><p>
# TrainOutput(global_step=480, training_loss=0.11357930699984232, metrics={'train_runtime': 3417.8668, 'train_samples_per_second': 0.562, 'train_steps_per_second': 0.14, 'total_flos': 0.0, 'train_loss': 0.11357930699984232, 'epoch': 2.0})

# %%
evaluator(embedding_model)
# Out:
# {'pearson_cosine': 0.29055880137514484, 'spearman_cosine': 0.2802968087899397}

# %%
from sentence_transformers.trainer import SentenceTransformerTrainer
from sentence_transformers.training_args import SentenceTransformerTrainingArguments

from datasets import IterableDataset
# Step 1: Load the model from your checkpoint
embedding_model = SentenceTransformer("/content/drive/MyDrive/Colab Notebooks/GenAIproject/output/base_embedding_model/checkpoint-480")

# Step 2: Define the training arguments (run for 2 more epochs)
args = SentenceTransformerTrainingArguments(
    output_dir="/content/drive/MyDrive/Colab Notebooks/GenAIproject/output/base_embedding_model",
    num_train_epochs=3,
    per_device_train_batch_size=4,
    per_device_eval_batch_size=4,
    warmup_steps=100,
    fp16=True,
    eval_steps=100,                  # Run evaluation every 10 steps
    logging_steps=100,               # Log training metrics every 10 steps
    eval_strategy="steps",    # Required to evaluate during training
    logging_dir="./logs",
    save_strategy="epoch",          # Save checkpoint after each epoch
    report_to="none"                # Disable logging to external tools
)

train_loss = losses.CosineSimilarityLoss(model=embedding_model)

# Step 4: Initialize the trainer
trainer = SentenceTransformerTrainer(
    model=embedding_model,
    args=args,
    train_dataset=hf_dataset,
    loss=train_loss,
    evaluator=evaluator
)

# Step 5: Resume training
trainer.train(resume_from_checkpoint=True)
# Out:
# Computing widget examples:   0%|          | 0/1 [00:00<?, ?example/s]
#     <div>
#
#       <progress value='720' max='720' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [720/720 58:48, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Pearson Cosine</th>
#       <th>Spearman Cosine</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>500</td>
#       <td>0.178600</td>
#       <td>No log</td>
#       <td>0.267869</td>
#       <td>0.256959</td>
#     </tr>
#     <tr>
#       <td>600</td>
#       <td>0.158700</td>
#       <td>No log</td>
#       <td>0.293583</td>
#       <td>0.288357</td>
#     </tr>
#     <tr>
#       <td>700</td>
#       <td>0.157600</td>
#       <td>No log</td>
#       <td>0.273085</td>
#       <td>0.255395</td>
#     </tr>
#   </tbody>
# </table><p>
# TrainOutput(global_step=720, training_loss=0.053464014331499735, metrics={'train_runtime': 3542.0189, 'train_samples_per_second': 0.813, 'train_steps_per_second': 0.203, 'total_flos': 0.0, 'train_loss': 0.053464014331499735, 'epoch': 3.0})

# %%
evaluator(embedding_model)
# Out:
# {'pearson_cosine': 0.2731916042696001, 'spearman_cosine': 0.25503400628097517}
